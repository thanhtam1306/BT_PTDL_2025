# %% [markdown]
# ## Monte Carlo - Predicting Gross Profit - Part II

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Proceed from where we left off on the previous exercise.

# %%
import numpy as np
import matplotlib.pyplot as plt

rev_m = 200
rev_stdev = 10
iterations = 256

rev = np.random.normal(rev_m, rev_stdev, iterations)
COGS = - (rev * np.random.normal(0.4,0.2))

COGS.mean(), COGS.std()
# Out:
# (np.float64(-82.07444446666008), np.float64(4.185446983916614))

# %% [markdown]
# ****

# %% [markdown]
# Based on the predicted revenue and Cogs values, estimate the expected Gross Profit of your company.

# %% [markdown]
# *Reminder: Be careful about estimating the gross profit. If you have stored the Cogs value as a negative number, the gross profit will equal revenues plus Cogs. If you have created Cogs as a positive value, then gross profit would be equal to revenues minus Cogs. Either way, you will obtain the same result for gross profit.*

# %%
Gross_Profit = rev + COGS
Gross_Profit
# Out:
# array([116.60670818, 122.09788452, 119.08757056, 120.924219  ,
#        111.6102095 , 118.15559138, 106.5904238 , 125.68551006,
#        114.12943563, 121.39171681, 120.84361798, 122.52235135,
#        115.26480342, 119.61336814, 113.5518103 , 119.70022076,
#        120.47462497, 112.06391801, 121.70548034, 119.50561029,
#        126.58830456, 130.13502967, 115.77908076, 112.67927113,
#        122.35407454, 111.70799814, 124.34195014, 114.96973969,
#        121.97917812, 121.12139868, 113.43204772, 109.62909918,
#        116.62282164, 120.95557685, 127.45868177, 122.50909993,
#        115.32674492, 111.15133901, 122.80479925, 132.68216052,
#        118.17070251, 127.97394692, 125.18600671, 114.3038775 ,
#        105.74069729, 128.52321495, 112.33049228, 113.75859787,
#        115.06578896, 116.96213323, 101.06465898, 117.09509895,
#        114.17025406, 116.19011458, 112.87534255, 113.47773992,
#        128.28900622, 114.38714995, 123.97978973, 120.36249632,
#        120.63079191, 120.83699284, 129.0109842 , 122.57031378,
#        110.19171867, 121.35569105, 116.97750805, 116.81044377,
#        117.98839296, 130.7587446 , 118.29895332, 117.81943712,
#        108.20861174, 120.13012405, 114.05064365, 113.10548416,
#        112.73071406, 113.74468136, 117.87530845, 125.35116075,
#        129.57168444, 117.39058721, 123.94350352, 113.13474969,
#        119.63855607, 120.31070233, 115.45608614, 123.72802491,
#        123.02190173, 122.62527224, 122.54308632, 123.44771019,
#        126.62266141, 126.11141152, 115.08225078, 108.87896375,
#        122.30459402, 113.18871641, 118.17112077, 107.51366458,
#        117.61502057, 117.08590521, 124.47464529, 118.36222711,
#        111.23876794, 110.06162583, 130.4779701 , 119.61747131,
#        116.71087289, 122.75633828, 105.36022246, 129.03851078,
#        109.51196845, 110.95477293, 121.0205509 , 119.31034205,
#        118.16342783, 127.17144128, 114.04076622, 117.09913375,
#        120.81651885, 116.24603496, 128.12606794, 128.15579865,
#        126.16895575, 118.39916758, 119.50748932, 109.69566408,
#        119.02463588, 117.19585699, 120.29197384, 112.65285665,
#        119.9700157 , 126.42287545, 116.02611612, 124.56023016,
#        116.93753746, 109.58766045, 107.72224197, 110.58484804,
#        118.32521536, 114.4918451 , 111.96015828, 117.15896276,
#        113.65752   , 116.88322261, 121.92463337, 128.18869332,
#        113.63660955, 118.93750988, 117.38053245, 122.53586267,
#        112.37979668, 110.2509022 , 110.8172181 , 120.82701594,
#        117.48436416, 106.81447818, 113.08960126, 120.68600761,
#        114.38289293, 115.69529488, 125.08205558, 131.00838209,
#        110.4385721 , 110.25365049, 124.35511768, 112.89080406,
#        112.16876208, 112.60638828, 119.07676357, 127.20259098,
#        113.38865507, 107.02395005, 124.73100294, 130.7932343 ,
#        111.05020258, 120.02029345, 125.23301259, 128.77242864,
#        124.02119276, 119.45458002, 115.88186556, 112.4237638 ,
#        125.8158816 , 129.52875223, 112.57425999, 125.32345696,
#        106.57989498, 120.82236955, 118.85347389, 119.68229368,
#        126.92603097, 122.02964424, 115.50304839, 117.95737886,
#        114.8593618 , 117.47030457, 111.17935045, 123.72629994,
#        119.56998613, 122.10427065, 122.43709187, 118.52223665,
#        112.83860248, 123.98821392, 132.45093589, 123.36416482,
#        114.64696793, 118.6171538 , 110.45216651, 109.99866795,
#        112.93703739, 124.24658513, 114.14933387, 123.29176958,
#        119.63589819, 119.28917309, 119.15894817, 109.63710631,
#        115.54185677, 114.77523015, 118.13087652, 118.24588007,
#        117.32522293, 124.90680761, 117.5932059 , 122.19947792,
#        111.62132829, 124.71861865, 125.29780943, 129.76766853,
#        127.37802832, 114.12605951, 115.78919231, 120.94806295,
#        108.89155976, 111.0938335 , 117.21151891, 121.57076844,
#        112.10329323, 104.71445557, 128.56237525, 114.26022566,
#        112.68709881, 119.8261423 , 121.88391981, 113.41036021,
#        115.13728737, 119.70567992, 117.56811708, 117.55978209,
#        123.56397485, 114.56869629, 116.84488855, 119.79869971])

# %% [markdown]
# What is the maximum and what is the minimum gross profit value you obtained?

# %%
plt.figure(figsize=(15, 6))
plt.plot(Gross_Profit)
plt.show()

# %%
max(Gross_Profit)
# Out:
# np.float64(132.68216051586904)

# %%
min(Gross_Profit)
# Out:
# np.float64(101.06465898301522)

# %% [markdown]
# What is its mean and standard deviation?

# %%
Gross_Profit.mean()
# Out:
# np.float64(118.31968272582216)

# %%
Gross_Profit.std()
# Out:
# np.float64(6.0337997097736)

# %% [markdown]
# Do you remember what a histogram is? Plot the gross profit data on a histogram. Use 20 bins directly to check the distribution of the data.

# %%
plt.figure(figsize=(10, 6));
plt.hist(Gross_Profit, bins = 20);
plt.show()
