# %% [markdown]
# ## Calculating the Beta of a Stock

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Obtain data for Microsoft and S&P 500 for the period 1st of January 2012 – 31st of December 2016 from Yahoo Finance.

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import yfinance as yf

tickers = ['MSFT', '^GSPC']
data = pd.DataFrame()
for t in tickers:
    data[t] = yf.download(t, start='2012-1-1', end='2016-12-31')['Close']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21756\3460162477.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data[t] = yf.download(t, start='2012-1-1', end='2016-12-31')['Close']
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21756\3460162477.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data[t] = yf.download(t, start='2012-1-1', end='2016-12-31')['Close']
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Let S&P 500 act as the market.

# %% [markdown]
# *****

# %% [markdown]
# Calculate the beta of Microsoft.

# %%
sec_returns = np.log( data / data.shift(1) )

# %%
cov = sec_returns.cov() * 250
cov
# Out:
#            MSFT     ^GSPC
# MSFT   0.053781  0.018213
# ^GSPC  0.018213  0.016362

# %%
cov_with_market = cov.iloc[0,1]
cov_with_market
# Out:
# np.float64(0.018212768882692926)

# %%
market_var = sec_returns['^GSPC'].var() * 250
market_var
# Out:
# np.float64(0.01636163100230847)

# %% [markdown]
# ** Beta: **
# ### $$
# \beta_{pg} = \frac{\sigma_{pg,m}}{\sigma_{m}^2}
# $$

# %%
MSFT_beta = cov_with_market / market_var
MSFT_beta
# Out:
# np.float64(1.1131389578534852)
