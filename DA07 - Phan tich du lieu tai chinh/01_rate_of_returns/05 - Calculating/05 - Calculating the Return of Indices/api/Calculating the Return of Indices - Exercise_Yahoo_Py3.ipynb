# %% [markdown]
# ## Calculating the Return of Indices

# %% [markdown]
# Consider three famous American market indices – Dow Jones, S&P 500, and the Nasdaq for the period of 1st of January 2000 until today.

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import yfinance as yf

# %%
tickers = ['^DJI', '^GSPC', '^IXIC']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = yf.download(t, start='2000-1-1')['Close']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19124\3408229157.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   ind_data[t] = yf.download(t, start='2000-1-1')['Close']
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19124\3408229157.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   ind_data[t] = yf.download(t, start='2000-1-1')['Close']
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19124\3408229157.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   ind_data[t] = yf.download(t, start='2000-1-1')['Close']
# [*********************100%***********************]  1 of 1 completed

# %%
ind_data.head()
# Out:
#                     ^DJI        ^GSPC        ^IXIC
# Date
# 2000-01-03  11357.509766  1455.219971  4131.149902
# 2000-01-04  10997.929688  1399.420044  3901.689941
# 2000-01-05  11122.650391  1402.109985  3877.540039
# 2000-01-06  11253.259766  1403.449951  3727.129883
# 2000-01-07  11522.559570  1441.469971  3882.620117

# %%
ind_data.tail()
# Out:
#                     ^DJI        ^GSPC         ^IXIC
# Date
# 2025-10-23  46734.609375  6738.439941  22941.800781
# 2025-10-24  47207.121094  6791.689941  23204.869141
# 2025-10-27  47544.589844  6875.160156  23637.460938
# 2025-10-28  47706.371094  6890.890137  23827.490234
# 2025-10-29  47632.000000  6890.589844  23958.470703

# %% [markdown]
# Normalize the data to 100 and plot the results on a graph.

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()

# %% [markdown]
# How would you explain the common and the different parts of the behavior of the three indices?

# %% [markdown]
# *****

# %% [markdown]
# Obtain the simple returns of the indices.

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1

ind_returns.tail()
# Out:
#                 ^DJI     ^GSPC     ^IXIC
# Date
# 2025-10-23  0.003095  0.005827  0.008857
# 2025-10-24  0.010111  0.007902  0.011467
# 2025-10-27  0.007149  0.012290  0.018642
# 2025-10-28  0.003403  0.002288  0.008039
# 2025-10-29 -0.001559 -0.000044  0.005497

# %% [markdown]
# Estimate the average annual return of each index.

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^DJI     0.072032
# ^GSPC    0.078566
# ^IXIC    0.098541
# dtype: float64
