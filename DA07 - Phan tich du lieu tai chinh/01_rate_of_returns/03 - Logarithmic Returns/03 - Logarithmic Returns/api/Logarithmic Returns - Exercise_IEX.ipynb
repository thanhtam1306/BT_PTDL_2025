# %% [markdown]
# ## Logarithmic Returns

# %%
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import yfinance as yf
MSFT = yf.download('MSFT', start='2015-1-1')
MSFT
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_25100\1469847394.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   MSFT = yf.download('MSFT', start='2015-1-1')
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2015-01-02   39.933064   40.496704   39.745186   39.847665  27913900
# 2015-01-05   39.565849   39.907448   39.497528   39.600007  39673900
# 2015-01-06   38.985107   39.924506   38.891167   39.608527  36447900
# 2015-01-07   39.480438   39.676858   38.848480   39.266938  29114100
# 2015-01-08   40.641876   40.778516   39.898897   39.924516  29645200
# ...                ...         ...         ...         ...       ...
# 2025-10-23  520.559998  523.950012  518.609985  522.460022  14023500
# 2025-10-24  523.609985  525.349976  520.710022  522.789978  15532400
# 2025-10-27  531.520020  534.580017  529.010010  531.780029  18734700
# 2025-10-28  542.070007  553.719971  540.770020  550.000000  29986700
# 2025-10-29  541.549988  546.270020  536.729980  544.940002  35368400
#
# [2723 rows x 5 columns]

# %% [markdown]
# ### Log Returns

# %% [markdown]
# $$
# ln(\frac{P_t}{P_{t-1}})
# $$

# %% [markdown]
# Calculate the Log returns for Microsoft.

# %%
MSFT.head()
# Out:
# Price           Close       High        Low       Open    Volume
# Ticker           MSFT       MSFT       MSFT       MSFT      MSFT
# Date
# 2015-01-02  39.933064  40.496704  39.745186  39.847665  27913900
# 2015-01-05  39.565849  39.907448  39.497528  39.600007  39673900
# 2015-01-06  38.985107  39.924506  38.891167  39.608527  36447900
# 2015-01-07  39.480438  39.676858  38.848480  39.266938  29114100
# 2015-01-08  40.641876  40.778516  39.898897  39.924516  29645200

# %%
MSFT['log_return'] = np.log(MSFT['Close'] / MSFT['Close'].shift(1))
print (MSFT['log_return'])
# Out:
# Date
# 2015-01-02         NaN
# 2015-01-05   -0.009238
# 2015-01-06   -0.014787
# 2015-01-07    0.012626
# 2015-01-08    0.028994
#                 ...
# 2025-10-23    0.000038
# 2025-10-24    0.005842
# 2025-10-27    0.014994
# 2025-10-28    0.019654
# 2025-10-29   -0.000960
# Name: log_return, Length: 2723, dtype: float64

# %% [markdown]
# Plot the results on a graph.

# %%
MSFT['log_return'].plot(figsize=(8, 5))
plt.show()

# %% [markdown]
# Estimate the daily and the annual mean of the obtained log returns.

# %%
log_return_d = MSFT['log_return'].mean()
log_return_d
# Out:
# np.float64(0.0009578364201573406)

# %%
log_return_a = MSFT['log_return'].mean() * 250
log_return_a
# Out:
# np.float64(0.23945910503933515)

# %% [markdown]
# Print the result in a presentable form.

# %%
print (str(round(log_return_a, 5) * 100) + ' %')
# Out:
# 23.946 %

# %% [markdown]
# ****

# %% [markdown]
# Repeat this exercise for any stock of interest to you. :)
