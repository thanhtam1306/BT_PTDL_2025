# %% [markdown]
# ## Logarithmic Returns

# %%
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import yfinance as yf
MSFT = yf.download('MSFT', start='2000-1-1')
MSFT
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15472\2836695617.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   MSFT = yf.download('MSFT', start='2000-1-1')
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2000-01-03   35.668079   36.299204   34.271956   35.916704  53228400
# 2000-01-04   34.463219   35.840217   34.348469   34.750093  54119000
# 2000-01-05   34.826576   35.610700   33.468703   34.004202  64059600
# 2000-01-06   33.659958   34.845706   33.162709   34.329332  54976600
# 2000-01-07   34.099831   34.348455   32.837582   33.239207  62013600
# ...                ...         ...         ...         ...       ...
# 2025-10-23  520.559998  523.950012  518.609985  522.460022  14023500
# 2025-10-24  523.609985  525.349976  520.710022  522.789978  15532400
# 2025-10-27  531.520020  534.580017  529.010010  531.780029  18734700
# 2025-10-28  542.070007  553.719971  540.770020  550.000000  29986700
# 2025-10-29  541.549988  546.270020  536.729980  544.940002  35368400
#
# [6496 rows x 5 columns]

# %% [markdown]
# ### Log Returns

# %% [markdown]
# $$
# ln(\frac{P_t}{P_{t-1}})
# $$

# %% [markdown]
# Calculate the Log returns for Microsoft.

# %%
MSFT.head()
# Out:
# Price           Close       High        Low       Open    Volume
# Ticker           MSFT       MSFT       MSFT       MSFT      MSFT
# Date
# 2000-01-03  35.668079  36.299204  34.271956  35.916704  53228400
# 2000-01-04  34.463219  35.840217  34.348469  34.750093  54119000
# 2000-01-05  34.826576  35.610700  33.468703  34.004202  64059600
# 2000-01-06  33.659958  34.845706  33.162709  34.329332  54976600
# 2000-01-07  34.099831  34.348455  32.837582  33.239207  62013600

# %%
MSFT['log_return'] = np.log(MSFT['Close'] / MSFT['Close'].shift(1))
print (MSFT['log_return'])
# Out:
# Date
# 2000-01-03         NaN
# 2000-01-04   -0.034364
# 2000-01-05    0.010488
# 2000-01-06   -0.034072
# 2000-01-07    0.012983
#                 ...
# 2025-10-23    0.000038
# 2025-10-24    0.005842
# 2025-10-27    0.014994
# 2025-10-28    0.019654
# 2025-10-29   -0.000960
# Name: log_return, Length: 6496, dtype: float64

# %% [markdown]
# Plot the results on a graph.

# %%
MSFT['log_return'].plot(figsize=(8, 5))
plt.show()

# %% [markdown]
# Estimate the daily and the annual mean of the obtained log returns.

# %%
log_return_d = MSFT['log_return'].mean()
log_return_d
# Out:
# np.float64(0.0004188112736031337)

# %%
log_return_a = MSFT['log_return'].mean() * 250
log_return_a
# Out:
# np.float64(0.10470281840078342)

# %% [markdown]
# Print the result in a presentable form.

# %%
print (str(round(log_return_a, 5) * 100) + ' %')
# Out:
# 10.47 %

# %% [markdown]
# ****

# %% [markdown]
# Repeat this exercise for any stock of interest to you. :)
