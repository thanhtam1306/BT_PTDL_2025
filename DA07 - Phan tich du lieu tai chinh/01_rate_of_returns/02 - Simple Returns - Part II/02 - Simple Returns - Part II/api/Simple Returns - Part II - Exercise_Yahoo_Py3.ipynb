# %% [markdown]
# ## Simple Returns - Part II

# %% [markdown]
# $$
# \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1
# $$

# %%
import numpy as np
from pandas_datareader import data as wb
import yfinance as yf
MSFT = yf.download('MSFT', start='2000-1-1')
MSFT['simple_return'] = (MSFT['Close'] / MSFT['Close'].shift(1)) - 1
print (MSFT['simple_return'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17468\1766805992.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   MSFT = yf.download('MSFT', start='2000-1-1')
# [*********************100%***********************]  1 of 1 completed
# Date
# 2000-01-03         NaN
# 2000-01-04   -0.033781
# 2000-01-05    0.010544
# 2000-01-06   -0.033498
# 2000-01-07    0.013068
#                 ...
# 2025-10-23    0.000038
# 2025-10-24    0.005859
# 2025-10-27    0.015107
# 2025-10-28    0.019849
# 2025-10-29   -0.000959
# Name: simple_return, Length: 6496, dtype: float64

# %% [markdown]
# Plot the simple returns on a graph.

# %%
import matplotlib.pyplot as plt
MSFT['simple_return'].plot(figsize=(8, 5))
plt.show()

# %% [markdown]
# Calculate the average daily return.

# %%
avg_returns_d = MSFT['simple_return'].mean()
avg_returns_d
# Out:
# np.float64(0.0005979921361910824)

# %% [markdown]
# Estimate the average annual return.

# %%
avg_returns_a = MSFT['simple_return'].mean() * 250
avg_returns_a
# Out:
# np.float64(0.1494980340477706)

# %% [markdown]
# Print the percentage version of the result as a float with 2 digits after the decimal point.

# %%
print (str(round(avg_returns_a, 4) * 100) + ' %')
# Out:
# 14.95 %
