# %% [markdown]
# ## Importing and Organizing Your Data in Python - Part I

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# a. Create a series object of 10 randomly generated integer values.

# %%
import numpy as np
import pandas as pd

# %%
ser = pd.Series(np.random.randint(10, size = 10, dtype = 'int'), name = "Column 01")

# %%
ser
# Out:
# 0    6
# 1    0
# 2    6
# 3    9
# 4    1
# 5    9
# 6    8
# 7    0
# 8    8
# 9    8
# Name: Column 01, dtype: int64

# %% [markdown]
# b. Extract data from IEX for Ford from the 1st of January 2015. The ticker you need is ‘F’.

# %%
from pandas_datareader import data as wb
import yfinance as yf

# %%
F = yf.download('F', start='2015-1-1')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4332\2890590292.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   F = yf.download('F', start='2015-1-1')
# [*********************100%***********************]  1 of 1 completed

# %%
F
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker              F          F          F          F          F
# Date
# 2015-01-02   8.626945   8.789823   8.525848   8.756124   24777900
# 2015-01-05   8.289952   8.497763   8.250636   8.492146   44079700
# 2015-01-06   8.211320   8.368582   8.076524   8.357349   32981600
# 2015-01-07   8.447215   8.475298   8.295570   8.301186   26065300
# 2015-01-08   8.660642   8.694340   8.553928   8.649408   33943400
# ...               ...        ...        ...        ...        ...
# 2025-10-23  12.340000  12.490000  12.190000  12.470000  479840300
# 2025-10-24  13.840000  13.970000  12.710000  12.730000  298366900
# 2025-10-27  13.260000  13.800000  13.210000  13.800000  140859000
# 2025-10-28  13.130000  13.280000  13.040000  13.240000   96738500
# 2025-10-29  13.240000  13.390000  13.070000  13.100000  127404100
#
# [2723 rows x 5 columns]
