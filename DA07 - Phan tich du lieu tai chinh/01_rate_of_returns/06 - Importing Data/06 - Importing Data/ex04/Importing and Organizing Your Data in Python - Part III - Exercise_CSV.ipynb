# %% [markdown]
# ## Importing and Organizing Your Data in Python - Part III

# %% [markdown]
# Save the data obtained in the previous exercise as a csv file. Then, save it in an excel format. <br />
# Do you remember which library can help you do that? Don’t forget to import it first!

# %%
import pandas as pd
from pandas_datareader import data as wb 
import yfinance as yf

# %%
tickers = ['AAPL', 'MSFT', 'XOM', 'BP']
new_data = pd.DataFrame()
for t in tickers:
    new_data[t] = yf.download(t, start='2015-1-1')['Close']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17872\4180217433.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   new_data[t] = yf.download(t, start='2015-1-1')['Close']
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17872\4180217433.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   new_data[t] = yf.download(t, start='2015-1-1')['Close']
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17872\4180217433.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   new_data[t] = yf.download(t, start='2015-1-1')['Close']
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17872\4180217433.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
# ...

# %%
new_data.to_csv(r'C:\Users\Admin\OneDrive\Documents\bt ptdl\bt_tuan_ptdl\DA07 - Phan tich du lieu tai chinh\01_rate_of_returns\06 - Importing Data\06 - Importing Data\ex04\example_01.csv')

# %%
new_data.to_excel(r'C:\Users\Admin\OneDrive\Documents\bt ptdl\bt_tuan_ptdl\DA07 - Phan tich du lieu tai chinh\01_rate_of_returns\06 - Importing Data\06 - Importing Data\ex04\example_01.xlsx')
