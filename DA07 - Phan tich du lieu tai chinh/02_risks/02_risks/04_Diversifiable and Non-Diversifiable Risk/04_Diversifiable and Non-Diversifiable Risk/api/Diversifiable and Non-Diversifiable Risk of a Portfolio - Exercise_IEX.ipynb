# %% [markdown]
# ## Diversifiable and Non-Diversifiable Risk of a Portfolio

# %% [markdown]
# Import the same dataset we used in the previous lecture – Microsoft and Apple stock, downloaded from IEX. Timeframe – 1st of January 2015 until today. <br />
# *Hint: To save time, we have written the code you need!*

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import yfinance as yf

tickers = ['MSFT', 'AAPL']
sec_data = pd.DataFrame()
for t in tickers:
    sec_data[t] = yf.download(t, start='2015-1-1')['Close']
    
sec_data
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10880\517794828.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sec_data[t] = yf.download(t, start='2015-1-1')['Close']
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10880\517794828.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sec_data[t] = yf.download(t, start='2015-1-1')['Close']
# [*********************100%***********************]  1 of 1 completed
#                   MSFT        AAPL
# Date
# 2015-01-02   39.933056   24.261045
# 2015-01-05   39.565834   23.577568
# 2015-01-06   38.985123   23.579796
# 2015-01-07   39.480419   23.910437
# 2015-01-08   40.641884   24.829126
# ...                ...         ...
# 2025-10-23  520.559998  259.579987
# 2025-10-24  523.609985  262.820007
# 2025-10-27  531.520020  268.809998
# 2025-10-28  542.070007  269.000000
# 2025-10-29  541.549988  269.700012
#
# [2723 rows x 2 columns]

# %%
sec_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2723 entries, 2015-01-02 to 2025-10-29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   MSFT    2723 non-null   float64
#  1   AAPL    2723 non-null   float64
# dtypes: float64(2)
# memory usage: 63.8 KB

# %% [markdown]
# Then, calculate the diversifiable and the non-diversifiable risk of a portfolio, composed of these two stocks:

# %% [markdown]
# a) with weights 0.5 and 0.5;

# %%
sec_returns = np.log(sec_data / sec_data.shift(1))
sec_returns
# Out:
#                 MSFT      AAPL
# Date
# 2015-01-02       NaN       NaN
# 2015-01-05 -0.009238 -0.028576
# 2015-01-06 -0.014786  0.000094
# 2015-01-07  0.012625  0.013925
# 2015-01-08  0.028994  0.037702
# ...              ...       ...
# 2025-10-23  0.000038  0.004363
# 2025-10-24  0.005842  0.012405
# 2025-10-27  0.014994  0.022535
# 2025-10-28  0.019654  0.000707
# 2025-10-29 -0.000960  0.002599
#
# [2723 rows x 2 columns]

# %% [markdown]
# ### Calculating Portfolio Variance

# %% [markdown]
# Equal weightings scheme:

# %%
weights = np.array([0.5, 0.5])

# %% [markdown]
# Portfolio Variance:

# %%
pfolio_var = np.dot(weights.T, np.dot(sec_returns.cov() * 250, weights))
pfolio_var
# Out:
# np.float64(0.0647862432161349)

# %% [markdown]
# ### Calculating Diversifiable and Non-Diversifiable Risk of a Portfolio

# %% [markdown]
# Diversifiable Risk:

# %%
MSFT_var_a = sec_returns[['MSFT']].var() * 250
MSFT_var_a
# Out:
# MSFT    0.072045
# dtype: float64

# %%
AAPL_var_a = sec_returns[['AAPL']].var() * 250
AAPL_var_a
# Out:
# AAPL    0.083424
# dtype: float64

# %% [markdown]
# Or:

# %%
MSFT_var_a = sec_returns['MSFT'].var() * 250
MSFT_var_a
# Out:
# np.float64(0.07204451910318747)

# %%
AAPL_var_a = sec_returns['AAPL'].var() * 250
AAPL_var_a
# Out:
# np.float64(0.0834239559060985)

# %% [markdown]
# Calculating Diversifiable Risk:

# %%
dr = pfolio_var - (weights[0] ** 2 * MSFT_var_a) - (weights[1] ** 2 * AAPL_var_a)
dr
# Out:
# np.float64(0.0259191244638134)

# %%
print (str(round(dr*100, 3)) + ' %')
# Out:
# 2.592 %

# %% [markdown]
# Calculating Non-Diversifiable Risk:

# %%
n_dr_1 = pfolio_var - dr
n_dr_1
# Out:
# np.float64(0.038867118752321496)

# %%
n_dr_2 = (weights[0] ** 2 * MSFT_var_a) + (weights[1] ** 2 * AAPL_var_a)
n_dr_2
# Out:
# np.float64(0.03886711875232149)

# %% [markdown]
# *****

# %% [markdown]
# b)	With weights 0.2 for Microsoft and 0.8 for Apple.

# %% [markdown]
# ### Calculating Portfolio Variance

# %%
weights_2 = np.array([0.2, 0.8])

# %% [markdown]
# Portfolio Variance:

# %%
pfolio_var_2 = np.dot(weights_2.T, np.dot(sec_returns.cov() * 250, weights_2))
pfolio_var_2
# Out:
# np.float64(0.07286135220087112)

# %% [markdown]
# ### Calculating Diversifiable and Non-Diversifiable Risk of a Portfolio

# %% [markdown]
# Calculating Diversifiable Risk:

# %%
dr_2 = pfolio_var_2 - (weights_2[0] ** 2 * MSFT_var_a) - (weights_2[1] ** 2 * AAPL_var_a)
dr_2
# Out:
# np.float64(0.016588239656840573)

# %%
print (str(round(dr*100, 3)) + ' %')
# Out:
# 2.592 %

# %% [markdown]
# Calculating Non-Diversifiable Risk:

# %%
n_dr_2 = pfolio_var_2 - dr_2
n_dr_2
# Out:
# np.float64(0.05627311254403054)

# %%
n_dr_2 = (weights_2[0] ** 2 * MSFT_var_a) + (weights_2[1] ** 2 * AAPL_var_a)
n_dr_2
# Out:
# np.float64(0.05627311254403054)
