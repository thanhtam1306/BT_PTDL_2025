# %% [markdown]
# ## Calculating the Risk of a Security

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Load the data for Microsoft (‘MSFT’) for the period ‘2000-1-1’ until today. <br />
# Assess the daily and the annual risk of ‘MSFT’. Repeat the exercise for Apple for the same timeframe.

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\Admin\OneDrive\Documents\bt ptdl\bt_tuan_ptdl\DA07 - Phan tich du lieu tai chinh\02_risks\02_risks\01_Calculating the Risk of a Security\01_Calculating the Risk of a Security\csv\MSFT_AAPL_2000_2017.csv', index_col='Date')

# %%
returns = np.log(data / data.shift(1))
returns
# Out:
#                 MSFT      AAPL
# Date
# 1999-12-31       NaN       NaN
# 2000-01-03 -0.001607  0.085034
# 2000-01-04 -0.034364 -0.088078
# 2000-01-05  0.010489  0.014528
# 2000-01-06 -0.034072 -0.090514
# ...              ...       ...
# 2017-03-17  0.003552 -0.004988
# 2017-03-20  0.000924  0.010446
# 2017-03-21 -0.011151 -0.011518
# 2017-03-22  0.012690  0.011235
# 2017-03-23 -0.002463 -0.003542
#
# [4334 rows x 2 columns]

# %% [markdown]
# ### MSFT

# %% [markdown]
# Daily risk:

# %%
returns['MSFT'].std()
# Out:
# np.float64(0.01965694884940363)

# %% [markdown]
# Annual risk:

# %%
returns['MSFT'].std() * 250 ** 0.5
# Out:
# np.float64(0.31080365106770813)

# %% [markdown]
# ### Apple

# %% [markdown]
# Daily risk:

# %%
returns['AAPL'].std()
# Out:
# np.float64(0.027761934312069407)

# %% [markdown]
# Annual risk:

# %%
returns['AAPL'].std() * 250 ** 0.5
# Out:
# np.float64(0.43895472339059544)

# %% [markdown]
# ******

# %% [markdown]
# Store the volatilities of the two stocks in an array called “vols”.

# %%
vols = returns[['MSFT', 'AAPL']].std() * 250 ** 0.5
vols
# Out:
# MSFT    0.310804
# AAPL    0.438955
# dtype: float64

# %% [markdown]
# How are the two risk values different?
