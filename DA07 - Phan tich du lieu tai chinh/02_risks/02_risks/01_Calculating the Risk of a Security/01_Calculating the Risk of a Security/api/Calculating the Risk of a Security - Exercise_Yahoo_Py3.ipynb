# %% [markdown]
# ## Calculating the Risk of a Security

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Download the data for Microsoft (‘MSFT’) from Yahoo Finance for the period ‘2000-1-1’ until today. <br />
# Assess the daily and the annual risk of ‘MSFT’. Repeat the exercise for Apple for the same timeframe.

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import yfinance as yf

# %%
tickers = ['MSFT', 'AAPL']

data = pd.DataFrame()

for t in tickers:
    data[t] = yf.download(t, start='2000-1-1')['Close']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19564\486246478.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data[t] = yf.download(t, start='2000-1-1')['Close']
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19564\486246478.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data[t] = yf.download(t, start='2000-1-1')['Close']
# [*********************100%***********************]  1 of 1 completed

# %%
returns = np.log(data / data.shift(1))
returns
# Out:
#                 MSFT      AAPL
# Date
# 2000-01-03       NaN       NaN
# 2000-01-04 -0.034364 -0.088077
# 2000-01-05  0.010489  0.014527
# 2000-01-06 -0.034072 -0.090514
# 2000-01-07  0.012983  0.046281
# ...              ...       ...
# 2025-10-23  0.000038  0.004363
# 2025-10-24  0.005842  0.012405
# 2025-10-27  0.014994  0.022535
# 2025-10-28  0.019654  0.000707
# 2025-10-29 -0.000960  0.002599
#
# [6496 rows x 2 columns]

# %% [markdown]
# ### MSFT

# %% [markdown]
# Daily risk:

# %%
returns['MSFT'].std()
# Out:
# np.float64(0.01892811877733749)

# %% [markdown]
# Annual risk:

# %%
returns['MSFT'].std() * 250 ** 0.5
# Out:
# np.float64(0.2992798357929398)

# %% [markdown]
# ### Apple

# %% [markdown]
# Daily risk:

# %%
returns['AAPL'].std()
# Out:
# np.float64(0.025152260705240792)

# %% [markdown]
# Annual risk:

# %%
returns['AAPL'].std() * 250 ** 0.5
# Out:
# np.float64(0.3976921606545696)

# %% [markdown]
# ******

# %% [markdown]
# Store the volatilities of the two stocks in an array called “vols”.

# %%
vols = returns[['MSFT', 'AAPL']].std() * 250 ** 0.5
vols
# Out:
# MSFT    0.299280
# AAPL    0.397692
# dtype: float64

# %% [markdown]
# How are the two risk values different?
