# %% [markdown]
# # ex2_scientific1
# ## Nội dung bài
# Hien thị ngau nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngau nhien với $x_i, y_i \in \left[0, 1 \right]$
# + Mau sac $color_i$ ngau nhien voi $color_i \in \left[0, 1 \right]$
# + Diện tich $area_i = \pi * r_i^2$ voi sinh ngau nhien $r_i \in \left[0, 1 \right]$

# %% [markdown]
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hien thi rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2 # 0 to 15 point radii
# Out:
# CPU times: total: 0 ns
# Wall time: 3.34 μs

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x) :.2f}, {max(x) :.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y) :.2f}, {max(y) :.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors) :.2f}, {max(colors) :.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area) :.2f}, {max(area) :.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.02, 0.98]: 10 samples [[0.74465835 0.96220717 0.69695963 0.5500849  0.7782025  0.59784245
#  0.36945283 0.5176462  0.11992514 0.69756406]]
# + y: len=50, [0.02, 0.98]: 10 samples [[0.72032818 0.17156488 0.93352028 0.816691   0.23700866 0.32054461
#  0.85031386 0.04145638 0.27818007 0.0157906 ]]
# + colors: len=50, [0.02, 0.97]: 10 samples [[0.47035301 0.88858633 0.06034696 0.87379556 0.66703078 0.94231444
#  0.45231961 0.08033384 0.46552489 0.82230755]]
# + area: len=50, [0.21, 679.83]: 10 samples [[ 32.40841666 532.61715248   8.90670445  65.39833753 260.23394059
#  565.5897383  199.46411878 679.82648505 120.17232259 629.44550659]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Kết thúc
